# %%
import pandas as pd
import re
import string
from bs4 import BeautifulSoup
import nltk
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
import unicodedata
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

# %%
import pandas as pd
from prepare_nlp import basic_clean, tokenize, lemmatize, remove_stopwords
from acquire import get_data

# %%
def basic_clean_keep_code(string):
    '''
    Takes in a string, makes all characters lowercase, normalizes all characters, and removes unnnecessary special characters
    import re
    import unicodedata
    '''
    # Remove line breaks
    string = re.sub(r'\n', ' ', string)
    
    # Remove the urls
    string = re.sub(r'https?://[^\s]+', '', string)
    
    # lowercase all words
    lowered = string.lower()

    # normalize unicode characters using lowered
    normalized = unicodedata.normalize('NFKD', lowered).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    
    # replacing unnecessary characters from normalized
    cleaned = re.sub(r"[^a-z0-9'\s]", '', normalized)
    
    return cleaned

# %%
df = get_data()
df.head()
# Out:
#                                   repo     language  \
# 0                      BeatSwitch/lock          PHP
# 1           Boostport/kubernetes-vault           Go
# 2                     Hitomis/SpinMenu         Java
# 3                 IBDecodable/IBLinter        Swift
# 4  KieranLafferty/KLNoteViewController  Objective-C
#
#                                      readme_contents
# 0  # Lock - Acl for PHP 5.4+\n\n[![Build Status](...
# 1  # No Longer Being Maintained.\n\nThe integrati...
# 2  # SpinMenu\n[![Android Arsenal](https://img.sh...
# 3  # IBLinter\n[![Build Status](https://travis-ci...
# 4  KLNoteViewController\n=======\n\n<img src="htt...

# %%
df['readme_contents'].apply(lambda x: basic_clean(x))
# Out:
# 0      lock  acl for php 54\n\nbuild statushttpsimgs...
# 1      no longer being maintained\n\nthe integration...
# 2      spinmenu\nandroid arsenalhttpsimgshieldsiobad...
# 3      iblinter\nbuild statushttpstravisciorgibdecod...
# 4     klnoteviewcontroller\n\n\nimg srchttpsrawgithu...
#                             ...
# 95     reduxaxiosmiddleware\n\nnpm versionhttpsbadge...
# 96     emacs starter kit\n\nversion 3 of the emacs s...
# 97    simulacrum\n\n\ncontinuous integrationhttpsgit...
# 98    httpolice\n\n\n status\n image httpsimgshields...
# 99    div aligncenter\nh1dstph1\n\ndstphttpsgithubco...
# Name: readme_contents, Length: 100, dtype: object

# %%
# getting a string to play with
x = df['readme_contents'][0]

# %%
# examine and witing out cleaning steps
x
# Out:
# '# Lock - Acl for PHP 5.4+\n\n[![Build Status](https://img.shields.io/travis/BeatSwitch/lock/master.svg?style=flat-square)](https://travis-ci.org/BeatSwitch/lock)\n[![Code Climate](https://codeclimate.com/github/BeatSwitch/lock/badges/gpa.svg)](https://codeclimate.com/github/BeatSwitch/lock)\n[![Test Coverage](https://codeclimate.com/github/BeatSwitch/lock/badges/coverage.svg)](https://codeclimate.com/github/BeatSwitch/lock/coverage)\n[![Software License](https://img.shields.io/badge/license-MIT-brightgreen.svg?style=flat-square)](license.md)\n[![Packagist Version](https://img.shields.io/packagist/v/beatswitch/lock.svg?style=flat-square)](https://packagist.org/packages/beatswitch/lock)\n[![Total Downloads](https://img.shields.io/packagist/dt/beatswitch/lock.svg?style=flat-square)](https://packagist.org/packages/beatswitch/lock)\n\n<img width="100%" src="https://s3.eu-central-1.amazonaws.com/assets.beatswitch.com/lock_banner.png">\n\n> I\'m sad to say that Lock is currently not maintained. I won\'t be able to offer support or accept new contributions for the current time being. Other priorities are keeping me from putting the work into Lock that it deserves. Eventually I\'ll try to pick up work again but unfortunately I cannot say when. My thanks goes out to all the contributors and users.\n>\n> -- Dries\n\nLock is a flexible, driver based **Acl** package for **PHP 5.4+**.\n\nCreated by [Dries Vints](https://twitter.com/driesvints). Made possible thanks to [BeatSwitch](https://beatswitch.com). Inspired by [Authority](https://github.com/machuga/authority) by [Matthew Machuga](https://twitter.com/machuga). Logo by [Jerry Low](http://www.jerrylow.com).\n\n## Table of Contents\n\n- [Terminology](#terminology)\n- [Features](#features)\n- [Introduction](#introduction)\n- [Drivers](#drivers)\n- [Roadmap](#roadmap)\n- [Installation](#installation)\n- [Usage](#usage)\n    - [Implementing the Caller contract](#implementing-the-caller-contract)\n    - [Working with a static driver](#working-with-a-static-driver)\n    - [Working with a persistent driver](#working-with-a-persistent-driver)\n    - [Setting and checking permissions](#setting-and-checking-permissions)\n    - [Clearing permissions](#clearing-permissions)\n    - [Setting an action alias](#setting-an-action-alias)\n    - [Setting a God caller](#setting-a-god-caller)\n    - [Working with roles](#working-with-roles)\n    - [Working with conditions](#working-with-conditions)\n    - [Retrieving allowed or denied resources](#retrieving-allowed-or-denied-resources)\n    - [Using the LockAware trait](#using-the-lockaware-trait)\n- [Api](#api)\n- [Building a driver](#building-a-driver)\n    - [Testing your driver](#testing-your-driver)\n- [Maintainer](#maintainer)\n- [Contributing](#contributing)\n- [Changelog](#changelog)\n- [License](#license)\n\n## Terminology\n\n- `Lock`: An acl instance for a subject. This package currently ships with a `CallerLock` and a `RoleLock` \n- `Caller`: An identity object that can have permissions to do something\n- `Driver`: A storage system for permissions which can either be static or persistent\n- `Permission`: A permission holds an action and an optional (unique) resource. Can be either a `Restriction` or a `Privilege`\n- `Restriction`: A restriction denies you from being able to perform an action (on an optional resource)\n- `Privilege`: A privilege allows you to perform an action (on an optional resource)\n- `Action`: An action is something you are either allowed or denied to do\n- `Resource`: A resource can be an object where you can perform one or more actions on. It can either target a certain type of resource or a specific resource by its unique identifier\n- `Role`: A role can also hold multiple permissions. A caller can have multiple roles. Roles can inherit permissions from other roles\n\n## Features\n\n- Flexible acl permissions for multiple identities (callers)\n- Static or persistent drivers to store permissions\n- Action aliases\n- Roles\ ...

# %% [markdown]
# #### Takeaways:
# * replace all \n with ' '
# * table of contents
# * areas of interest: **___** for highlighted text, ## for headers, `highlighted text`, ```code block```, [topic](linktoinfoontopic)
#
#
# #### Actions:
# * Column1:
#     * First, remove all \n and replace wih spaces
#     * Remove all websites
#     * Remove all special characters
# * Column 2
#     * Remove all \n and replace wih spaces
#     * Remove all websites
#     * Remove all code blocks
#     * Remove all special characters

# %%
# beginning column 1 actions
# Remove line breaks
x = re.sub(r'\n', ' ', x)

# %%
# finding the websites
regexp = r'https?://[^\s]+'
subject = x
# re.findall(regexp, subject)

# replacing the websites
x = re.sub(regexp, ' ', x)

# %%
basic_clean_keep_code(x)
# Out:
# " lock  acl for php 54  build status  code climate  test coverage  software license  packagist version  total downloads   img width100 src    i'm sad to say that lock is currently not maintained i won't be able to offer support or accept new contributions for the current time being other priorities are keeping me from putting the work into lock that it deserves eventually i'll try to pick up work again but unfortunately i cannot say when my thanks goes out to all the contributors and users    dries  lock is a flexible driver based acl package for php 54  created by dries vints  made possible thanks to beatswitch  inspired by authority  by matthew machuga  logo by jerry low    table of contents   terminologyterminology  featuresfeatures  introductionintroduction  driversdrivers  roadmaproadmap  installationinstallation  usageusage      implementing the caller contractimplementingthecallercontract      working with a static driverworkingwithastaticdriver      working with a persistent driverworkingwithapersistentdriver      setting and checking permissionssettingandcheckingpermissions      clearing permissionsclearingpermissions      setting an action aliassettinganactionalias      setting a god callersettingagodcaller      working with rolesworkingwithroles      working with conditionsworkingwithconditions      retrieving allowed or denied resourcesretrievingallowedordeniedresources      using the lockaware traitusingthelockawaretrait  apiapi  building a driverbuildingadriver      testing your drivertestingyourdriver  maintainermaintainer  contributingcontributing  changelogchangelog  licenselicense   terminology   lock an acl instance for a subject this package currently ships with a callerlock and a rolelock   caller an identity object that can have permissions to do something  driver a storage system for permissions which can either be static or persistent  permission a permission holds an action and an optional unique resource can be either a restriction or a privilege  restriction a restriction denies you from being able to perform an action on an optional resource  privilege a privilege allows you to perform an action on an optional resource  action an action is something you are either allowed or denied to do  resource a resource can be an object where you can perform one or more actions on it can either target a certain type of resource or a specific resource by its unique identifier  role a role can also hold multiple permissions a caller can have multiple roles roles can inherit permissions from other roles   features   flexible acl permissions for multiple identities callers  static or persistent drivers to store permissions  action aliases  roles  conditions asserts  easily implement acl functionality on your caller or role with a trait   introduction  lock differs from other acl packages by trying to provide the most flexible way for working with multiple permission callers and storing permissions  by working with lock's caller contract you can set permissions on multiple identities  the driver contract allows for an easy way to store permissions to a persistent or static storage system a default static arraydriver ships with this package check out the list below for more drivers which have already been prepared for you or build your own by implementing the driver contract  you can set and check permissions for resources by manually passing along a resource's type and optional identifier or you can implement the resource contract onto your objects so you can pass them along to lock more easily  the manager allows for an easy way to instantiate new lock instances set action aliases or register roles   drivers  if you need a frameworkspecific implementation pick one of the already prepared drivers below   arraydriver ships with this package  laravel 5    roadmap   group permissions  more drivers symfony zend framework doctrine   event listeners   installation  install this package through composer  bash  composer req ...

# %%
# Testing the basica cleaning applied
df['basic_clean_1'] = df['readme_contents'].apply(lambda x: basic_clean_keep_code(x))

# %%
# getting tokenized form

# %%
def tokenize(string):
    '''
    Takes in a string and tokenizes the string
    Modules:
        from nltk.tokenize.toktok import ToktokTokenizer
    '''
    # initialize tokenizers
    tokenizer = nltk.tokenize.ToktokTokenizer()
    
    # tokenize string and store in tokenized
    tokenized = tokenizer.tokenize(string, return_str=True)
    
    return tokenized

# %%
def remove_stopwords(string, extra_words=[], exclude_words=[]):
    '''
    takes in a string and removes stopwords using the stopwords
    Modules:
         from nltk.corpus import stopwords
    '''
    # establish stop word list
    stop_word_list = stopwords.words('english')
    
    # if there are any words in the kwarg
    if bool(extra_words) == True:

        # add them to the stop_word_list
        stop_word_list = stop_word_list + extra_words

    # if there are any words in the kwarg
    if bool(exclude_words) == True:

        # remove them from the stop word list
        stop_word_list = [word for word in stop_word_list if word not in exclude_words]
        
    # getting a list of words from string argument that are not in the list of stop words (removing the stopwords)
    filtered = [word for word in string.split() if word not in stop_word_list]
    
    # rejoin all the words in the lsit with a space to reform string
    string_without_stopwords = ' '.join(filtered)
    
    # exit and return the string
    return string_without_stopwords

# %%
def cleaned_with_code_included(x):
    '''
    Takes in a string literal and performs cleaning, tokenizing, and removes the stop words
    
    '''
    # runs a basic clean
    x = basic_clean_keep_code(x)
    
    # tokenizes the words
    x = tokenize(x)
    
    # removes the stop words
    x = remove_stopwords(x)
    
    # returns string with all cleaning steps performed
    return x

# %%
# testing
df['readme_contents'].apply(lambda x: cleaned_with_code_included(x))
# Out:
# 0     lock acl php 54 build status code climate test...
# 1     longer maintained integration vault kubernetes...
# 2     spinmenu android arsenal fragment preview img ...
# 3     iblinter build status swift 50 linter tool nor...
# 4     klnoteviewcontroller img src width50 control o...
#                             ...
# 95    reduxaxiosmiddleware npm version redux middlew...
# 96    emacs starter kit version 3 emacs starter kit ...
# 97    simulacrum continuous integration maven centra...
# 98    httpolice status image target image target ima...
# 99    div aligncenter h1dstph1 dstp run common netwo...
# Name: readme_contents, Length: 100, dtype: object

# %%
# droppinf initial
df = df.drop('basic_clean_1', axis=1)

# %%
# initial cleaning completed
df['basic_clean_with_code'] = df['readme_contents'].apply(lambda x: cleaned_with_code_included(x))

# %%
def lemmatize(string):
    '''
    Takes in a string and returns it with all words in lemmatized form
    Modules:
        import nltk
    '''
    # initializing lematizing object
    wnl = nltk.stem.WordNetLemmatizer()

    # getting a list of root words from each word in the split string
    lemmas = [wnl.lemmatize(word) for word in string.split()]

    # rejoining the list of root words to form a lemmatized corpus
    lemmatized = ' '.join(lemmas)
    
    # exit and return lemmatized info
    return lemmatized

# %%
df['basic_clean_with_code'].apply(lambda x: lemmatize(x))
# Out:
# 0     lock acl php 54 build status code climate test...
# 1     longer maintained integration vault kubernetes...
# 2     spinmenu android arsenal fragment preview img ...
# 3     iblinter build status swift 50 linter tool nor...
# 4     klnoteviewcontroller img src width50 control o...
#                             ...
# 95    reduxaxiosmiddleware npm version redux middlew...
# 96    emacs starter kit version 3 emacs starter kit ...
# 97    simulacrum continuous integration maven centra...
# 98    httpolice status image target image target ima...
# 99    div aligncenter h1dstph1 dstp run common netwo...
# Name: basic_clean_with_code, Length: 100, dtype: object

# %%
# getting practice data
x = df['basic_clean_with_code'][27][-500:]

# %%
# initilializing wnl
wnl = nltk.stem.WordNetLemmatizer()

for word in x.split():
    print('original:', word, '-- lemma:', wnl.lemmatize(word))
# Out:
# original: repoopenwhiskopenwhisk -- lemma: repoopenwhiskopenwhisk
# original: microsoft -- lemma: microsoft
# original: azure -- lemma: azure
# original: functions -- lemma: function
# original: progress -- lemma: progress
# original: help -- lemma: help
# original: wanted -- lemma: wanted
# original: see -- lemma: see
# original: azure -- lemma: azure
# original: functions -- lemma: function
# original: reference -- lemma: reference
# original: example -- lemma: example
# original: local -- lemma: local
# original: testing -- lemma: testing
# original: script -- lemma: script
# original: bash -- lemma: bash
# original: environment -- lemma: environment
# original: variables -- lemma: variable
# original: export -- lemma: export
# original: azurestorageconnectionstring -- lemma: azurestorageconnectionstring
# original: copy -- lemma: copy
# original: azure -- lemma: azure
# original: console -- lemma: console
# original: export -- lemma: export
# original: configfileconfigmsajson -- lemma: configfileconfigmsajson
# original: node -- lemma: node
# original: version -- lemma: version
# original: nvm -- lemma: nvm
# original: use -- lemma: use
# original: 591 -- lemma: 591
# original: subject -- lemma: subject
# original: change -- lemma: change
# original: babelnode -- lemma: babelnode
# original: test -- lemma: test
# original: script -- lemma: script
# original: node -- lemma: node
# original: nodemodulesbabelclibinbabelnodejs -- lemma: nodemodulesbabelclibinbabelnodejs
# original: presets -- lemma: presets
# original: es2015node5 -- lemma: es2015node5
# original: testawsjs -- lemma: testawsjs
# original: contributing -- lemma: contributing
# original: submit -- lemma: submit
# original: issues -- lemma: issue
# original: find -- lemma: find
# original: bugs -- lemma: bug
# original: something -- lemma: something
# original: unclear -- lemma: unclear
# original: pull -- lemma: pull
# original: requests -- lemma: request
# original: even -- lemma: even
# original: better -- lemma: better
# original: especially -- lemma: especially
# original: make -- lemma: make
# original: something -- lemma: something
# original: generalized -- lemma: generalized
# original: use -- lemma: use
# original: star -- lemma: star

# %%
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
import spacy

# Load English tokenizer, tagger, parser and NER
nlp = spacy.load("en_core_web_sm")

# %%
def spacy_string(string):
    '''
    Takes in a string and returns it with all words in spacy-lemmatization form form
    Modules:
        import spacy
    '''
    # initializing lematizing object
    nlp = spacy.load('en_core_web_sm')
    
    # getting lemmatized words
    string_stemmed = [word.lemma_ for word in nlp(string)]
    
    # rejoining words
    string_stemmed = ' '.join(string_stemmed)
    
    # exit and return lemmatized info
    return string_stemmed

# %%
# getting spacy stemming
df['spacy'] = df['basic_clean_with_code'].apply(lambda x: spacy_string(x))

# %%
# getting lemmatized text
df['lem'] = df['basic_clean_with_code'].apply(lambda x: lemmatize(x))

# %%
# checking
df.head()
# Out:
#                                   repo     language  \
# 0                      BeatSwitch/lock          PHP
# 1           Boostport/kubernetes-vault           Go
# 2                     Hitomis/SpinMenu         Java
# 3                 IBDecodable/IBLinter        Swift
# 4  KieranLafferty/KLNoteViewController  Objective-C
#
#                                      readme_contents  \
# 0  # Lock - Acl for PHP 5.4+\n\n[![Build Status](...
# 1  # No Longer Being Maintained.\n\nThe integrati...
# 2  # SpinMenu\n[![Android Arsenal](https://img.sh...
# 3  # IBLinter\n[![Build Status](https://travis-ci...
# 4  KLNoteViewController\n=======\n\n<img src="htt...
#
#                                basic_clean_with_code  \
# 0  lock acl php 54 build status code climate test...
# 1  longer maintained integration vault kubernetes...
# 2  spinmenu android arsenal fragment preview img ...
# 3  iblinter build status swift 50 linter tool nor...
# 4  klnoteviewcontroller img src width50 control o...
#
#                                                spacy  \
# 0  lock acl php 54 build status code climate test...
# 1  long maintain integration vault kubernete grea...
# 2  spinmenu android arsenal fragment preview img ...
# 3  iblinter build status swift 50 linter tool nor...
# 4  klnoteviewcontroller img src width50 control o...
#
#                                                  lem
# 0  lock acl php 54 build status code climate test...
# 1  longer maintained integration vault kubernetes...
# 2  spinmenu android arsenal fragment preview img ...
# 3  iblinter build status swift 50 linter tool nor...
# 4  klnoteviewcontroller img src width50 control o...

# %%
# creating a basic_prepare function that does all of the above in one go

# %%
def basic_prepare(df):
    '''
    Takes in a df and adds columns with cleaned code
    '''
    
    # initial cleaning completed
    df['basic_clean_with_code'] = df['readme_contents'].apply(lambda x: cleaned_with_code_included(x))
    
    # getting spacy stemming
    df['spacy'] = df['basic_clean_with_code'].apply(lambda x: spacy_string(x))
    
    # getting lemmatized text
    df['lem'] = df['basic_clean_with_code'].apply(lambda x: lemmatize(x))
    
    return df

# %%
# testing the above function
df = get_data()

# %%
# success, not to create a prepare.py file
basic_prepare(df)
# Out:
#                                    repo     language  \
# 0                       BeatSwitch/lock          PHP
# 1            Boostport/kubernetes-vault           Go
# 2                      Hitomis/SpinMenu         Java
# 3                  IBDecodable/IBLinter        Swift
# 4   KieranLafferty/KLNoteViewController  Objective-C
# ..                                  ...          ...
# 95  svrcekmichal/redux-axios-middleware   JavaScript
# 96        technomancy/emacs-starter-kit         None
# 97                 typelevel/simulacrum        Scala
# 98                   vfaronov/httpolice       Python
# 99                             ycd/dstp           Go
#
#                                       readme_contents  \
# 0   # Lock - Acl for PHP 5.4+\n\n[![Build Status](...
# 1   # No Longer Being Maintained.\n\nThe integrati...
# 2   # SpinMenu\n[![Android Arsenal](https://img.sh...
# 3   # IBLinter\n[![Build Status](https://travis-ci...
# 4   KLNoteViewController\n=======\n\n<img src="htt...
# ..                                                ...
# 95  # redux-axios-middleware\n\n[![npm version](ht...
# 96  # Emacs Starter Kit\n\nVersion 3 of the Emacs ...
# 97  simulacrum\n==========\n\n[![Continuous Integr...
# 98  HTTPolice\n=========\n\n.. status:\n.. image::...
# 99  <div align="center">\n<h1>dstp</h1>\n\n[dstp](...
#
#                                 basic_clean_with_code  \
# 0   lock acl php 54 build status code climate test...
# 1   longer maintained integration vault kubernetes...
# 2   spinmenu android arsenal fragment preview img ...
# 3   iblinter build status swift 50 linter tool nor...
# 4   klnoteviewcontroller img src width50 control o...
# ..                                                ...
# 95  reduxaxiosmiddleware npm version redux middlew...
# 96  emacs starter kit version 3 emacs starter kit ...
# 97  simulacrum continuous integration maven centra...
# 98  httpolice status image target image target ima...
# 99  div aligncenter h1dstph1 dstp run common netwo...
#
#                                                 spacy  \
# 0   lock acl php 54 build status code climate test...
# 1   long maintain integration vault kubernete grea...
# 2   spinmenu android arsenal fragment preview img ...
# 3   iblinter build status swift 50 linter tool nor...
# 4   klnoteviewcontroller img src width50 control o...
# ..                                                ...
# 95  reduxaxiosmiddleware npm version redux middlew...
# 96  emacs starter kit version 3 emac starter kit i...
# 97  simulacrum continuous integration maven centra...
# 98  httpolice status image target image target ima...
# 99  div aligncenter h1dstph1 dstp run common netwo...
#
#                                                   lem
# 0   lock acl php 54 build status code climate test...
# 1   longer maintained integration vault kubernetes...
# 2   spinmenu android arsenal fragment preview img ...
# 3   iblinter build status swift 50 linter tool nor...
# 4   klnoteviewcontroller img src width50 control o...
# ..                                                ...
# 95  reduxaxiosmiddleware npm version redux middlew...
# 96  emacs starter kit version 3 emacs starter kit ...
# 97  simulacrum continuous integration maven centra...
# 98  httpolice status image target image target ima...
# 99  div aligncenter h1dstph1 dstp run common netwo...
#
# [100 rows x 6 columns]

# %%
import pandas as pd
import re
import unicode
import nltk
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords
import spacy


def basic_clean_keep_code(string):
    '''
    Takes in a string, makes all characters lowercase, normalizes all characters, and removes unnnecessary special characters
    import re
    import unicodedata
    '''
    # Remove line breaks
    string = re.sub(r'\n', ' ', string)
    
    # Remove the urls
    string = re.sub(r'https?://[^\s]+', '', string)
    
    # lowercase all words
    lowered = string.lower()

    # normalize unicode characters using lowered
    normalized = unicodedata.normalize('NFKD', lowered).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    
    # replacing unnecessary characters from normalized
    cleaned = re.sub(r"[^a-z0-9'\s]", '', normalized)
    
    return cleaned

def tokenize(string):
    '''
    Takes in a string and tokenizes the string
    Modules:
        from nltk.tokenize.toktok import ToktokTokenizer
    '''
    # initialize tokenizers
    tokenizer = nltk.tokenize.ToktokTokenizer()
    
    # tokenize string and store in tokenized
    tokenized = tokenizer.tokenize(string, return_str=True)
    
    return tokenized


def remove_stopwords(string, extra_words=[], exclude_words=[]):
    '''
    takes in a string and removes stopwords using the stopwords
    Modules:
         from nltk.corpus import stopwords
    '''
    # establish stop word list
    stop_word_list = stopwords.words('english')
    
    # if there are any words in the kwarg
    if bool(extra_words) == True:

        # add them to the stop_word_list
        stop_word_list = stop_word_list + extra_words

    # if there are any words in the kwarg
    if bool(exclude_words) == True:

        # remove them from the stop word list
        stop_word_list = [word for word in stop_word_list if word not in exclude_words]
        
    # getting a list of words from string argument that are not in the list of stop words (removing the stopwords)
    filtered = [word for word in string.split() if word not in stop_word_list]
    
    # rejoin all the words in the lsit with a space to reform string
    string_without_stopwords = ' '.join(filtered)
    
    # exit and return the string
    return string_without_stopwords

def cleaned_with_code_included(x):
    '''
    Takes in a string literal and performs cleaning, tokenizing, and removes the stop words
    
    '''
    # runs a basic clean
    x = basic_clean_keep_code(x)
    
    # tokenizes the words
    x = tokenize(x)
    
    # removes the stop words
    x = remove_stopwords(x)
    
    # returns string with all cleaning steps performed
    return x

def lemmatize(string):
    '''
    Takes in a string and returns it with all words in lemmatized form
    Modules:
        import nltk
    '''
    # initializing lematizing object
    wnl = nltk.stem.WordNetLemmatizer()

    # getting a list of root words from each word in the split string
    lemmas = [wnl.lemmatize(word) for word in string.split()]

    # rejoining the list of root words to form a lemmatized corpus
    lemmatized = ' '.join(lemmas)
    
    # exit and return lemmatized info
    return lemmatized

def spacy_string(string):
    '''
    Takes in a string and returns it with all words in spacy-lemmatization form form
    Modules:
        import spacy
    '''
    # initializing lematizing object
    nlp = spacy.load('en_core_web_sm')
    
    # getting lemmatized words
    string_stemmed = [word.lemma_ for word in nlp(string)]
    
    # rejoining words
    string_stemmed = ' '.join(string_stemmed)
    
    # exit and return lemmatized info
    return string_stemmed

def basic_prepare(df):
    '''
    Takes in a df and adds columns with cleaned code
    '''
    
    # initial cleaning completed
    df['basic_clean_with_code'] = df['readme_contents'].apply(lambda x: cleaned_with_code_included(x))
    
    # getting spacy stemming
    df['spacy'] = df['basic_clean_with_code'].apply(lambda x: spacy_string(x))
    
    # getting lemmatized text
    df['lem'] = df['basic_clean_with_code'].apply(lambda x: lemmatize(x))
    
    return df

# %%
from acquire import get_data
from prepare import basic_prepare

# get data
df = get_data()

# get prepared data
df = basic_prepare(df)

# check the gead
df.head()
